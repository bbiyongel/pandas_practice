# %%
import pandas as pd

# %%
df = pd.read_excel('../data/qa_dataset.xlsx')

# %%
df.head()
# Out:
#   intent                                           sentence  \
# 0   정비추천  2017년식 YF 쏘나타에 주행중 소음이나서 p0300 발생 브레이크 패드 교체하고...
# 1   정비추천                                   2016년식 제네시스 시동불량
# 2   정비추천                                          LF 백연 발생
# 3   정비추천                                   아이오닉 최근 문제 뭐가 있지
# 4   정비추천                                    싼타페 주행중 자석현상 발생
#
#                           question                        answer   대상
# 0  2017년식 쏘나타에 주행중 소음이나서 p0300 발생    브레이크 패드 교체하고 시운전 후 이상 없었습니다  NaN
# 1                 2016년식 제네시스 시동불량    블랙박스 암전류 영향으로 배터리 교환 필요합니다  NaN
# 2                         LF 백연 발생                   엔진오일 누유 같아요  NaN
# 3                 아이오닉 최근 문제 뭐가 있지        충전소 인프라 부족으로 고객불만이 큽니다  NaN
# 4                  싼타페 주행중 자석현상 발생   센서 전류 불안정하고 MDPS 교환이 필요합니다   NaN

# %%
str('a'+'-'+'b')
# Out:
# 'a-b'

# %%
str('aaaa')+df
# Out:
#       intent                                           sentence  \
# 0   aaaa정비추천  aaaa2017년식 YF 쏘나타에 주행중 소음이나서 p0300 발생 브레이크 패드 ...
# 1   aaaa정비추천                               aaaa2016년식 제네시스 시동불량
# 2   aaaa정비추천                                      aaaaLF 백연 발생
# 3   aaaa정비추천                               aaaa아이오닉 최근 문제 뭐가 있지
# 4   aaaa정비추천                                aaaa싼타페 주행중 자석현상 발생
# 5   aaaa정비추천                                       aaaa그랜저 시동꺼짐
# 6   aaaa정비추천                                        aaaa투싼 시동불가
# 7   aaaa정비추천                                       aaaaG70 엔진소음
# 8   aaaa정비추천                                    aaaa스팅어 브레이크 마모
# 9   aaaa정비추천                                     aaaa이 차 뭐가 문제야
# 10  aaaa정비지식                                   aaaaP0638 무슨 문제야
# 11    aaaa이력                               aaaa엔진오일 언제 갈았는지 알려줘
# 12    aaaa이력                                     aaaa정비소 추천 해줄래
# 13   aaaa트랜드                     aaaa2017년식 쏘나타에 무슨 문제가 있는지 알려줘
# ...

# %%
s = pd.Series('bbbb')

# %%
s+df
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\pandas\indexes\base.py:2482: RuntimeWarning: unorderable types: str() < int(), sort order is undefined for incomparable objects
#   return this.join(other, how=how, return_indexers=return_indexers)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     985             result = expressions.evaluate(op, str_rep, x, y,
# --> 986                                           raise_on_error=True, **eval_kwargs)
#     987         except TypeError:
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     208         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 209                          **eval_kwargs)
# ...
